# %%
10, 20, 30
# Out:
# (10, 20, 30)

# %%
a = (10, 20, 30)
type(a)
# Out:
# tuple

# %%
def my_func(t):
    for e in t:
        print(e)

# %%
my_func(10, 20, 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-aa26326b5603> in <module>
# ----> 1 my_func(10, 20, 30)
#
# TypeError: my_func() takes 1 positional argument but 3 were given

# %%
my_func((10, 20, 30))

# %%
a

# %%
a[0], a[-1]

# %%
a = 10, 20
type(a)

# %%
a = 10,
type(a)

# %%
a = 10, 20, 30 , 'India'
from collections.abc import Iterable

isinstance(a, Iterable)

# %%
for e in a:
    print(e)

# %%
a = 1, 2, 3, 4, 5, 6, 7, 8, 9

x, y, *another, z = a

# %%
another

# %%
a = 1, 2, 3, 4, 5, 6, 7, 8, 9

x, y, *_, z = a
print(_)

# %%
x

# %%
a[0]

# %%
class Point2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __repr__(self):
        return f'{self.__class__.__name__}(x={self.x}, y={self.y})'

# %%
pt = Point2D(10, 20)
pt

# %%
a = 10
print(f'rohan {a * 2} {pt}')

# %%
class Point2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __repr__(self):
        return f'{self.__class__.__name__}(x={self.x}, y={self.y})'

pt = Point2D(10, 20)
print(id(pt))
pt.x = 100
print(id(pt))

# %%
s = 'python'
print(id(s))
s += ' rocks'
print(id(s))

# %%
a = 1, 2, 3
print(id(a))
a += 4, 5
print(id(a))

# %%
a

# %%
# (x, y)
pt1 = (10, 20)
pt2 = (20, 30)

# %%
pt1[0] = 100

# %%
num = 1_000_000
type(num)

# %%
london = 'London', 'UK', 8_780_000
new_york = 'New York', 'USA', 8_500_000
beijing = 'Beijing', 'China', 21_000_000

london

# %%
cities = [london, new_york, beijing]

# %%
total = 0
for city in cities:
    total += city[2]
print(total)

# %%
sum(city[2] for city in cities)

# %%
record = 'BSE', 2018, 1, 19, 25_987, 26_072, 25_942, 26_072
symbol, year, month, day, open_, high, low, close = record

# %%
symbol, close

# %%
symbol, *_, close = record

# %%
symbol

# %%
for city in cities:
    print(city)

# %%
for city_name, country, population in cities:
    print(city_name)

# %%
for index, item in enumerate(cities):
    print(item)

# %%
record = 'BSE', 2018, 1, 19, 25_987, 26_072, 25_942, 26_072
symbol, year, month, day, open_, high, low, close = record

# %%
a = {1, 2, 3, 'rohan', 'abd'}
for index, item in enumerate(a):
    print(index, item)

# %%
from random import uniform
from math import sqrt

def random_shot(rad):
    r_x = uniform(-rad, rad)
    r_y = uniform(-rad, rad)

    if sqrt(r_x**2 + r_y**2) <= rad:
        is_in_circle = True
    else:
        is_in_circle = False
    
    return r_x, r_y, is_in_circle

# %%
num_attempts = 1000000
count_inside = 0

for i in range(num_attempts):
    *_, is_in_circle = random_shot(1)
    if is_in_circle:
        count_inside += 1

print(f'Approximate value of Pi is {4*count_inside/num_attempts} ')

# %%
t1 = ((1, 2), (3, 4))
t1[0] += (7, 8)

# %%
a = (1, 2, 3)
a += (5, 6)

# %%
class Point3D:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

# %%
from collections import namedtuple

# %%
Point2D = namedtuple('Point2D', 'x, y')

pt1 = Point2D(20, 40)
print(f'{pt1.x}  {pt1[0]}')

# %%
pt1

# %%
pt3d_1 = Point3D(10, 20, 30)
pt3d_1

# %%
Pt2D = namedtuple('Point2D', """
                    x
                                            y""")
pt2 = Pt2D(10, 20)
pt2

# %%
Point2D(10, 20)

# %%
p = Point3D(x=10, y=20, z=30)

# %%
p.x, p.y

# %%
p = Point2D(x=10, y=20)
p

# %%
p.x, p.y

# %%
isinstance(p, tuple)

# %%
a = (10, 20)
b = (10, 20)

a is b

# %%
a == b

# %%
pt1 = Point3D(10, 20, 30)
pt2 = Point3D(10, 20, 30)
pt1 == pt2

# %%
a = Point2D(x=10, y=20)
b = Point2D(x=10, y=20)
a == b

# %%
class Point3D:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

    def __repr__(self):
        return f'{self.__class__.__name__}(x={self.x}, y={self.y}, z={self.z})'

    def __eq__(self, other):
        if isinstance(other, Point3D):
            return self.x == other.x and self.y == other.y
        else:
            return False

# %%
pt1 = Point3D(10, 20, 30)
pt2 = Point3D(10, 20, 30)
print(pt1)
print(pt1 == pt2)

# %%
# sum(pt2)

a = Point2D(x=10, y=20)
sum(a)

# %%
pt2[0]

# %%
a[0]

# %%
a.x

# %%
def dot_product_3d(a, b):
    return a.x*b.x + a.y*b.y + a.z*b.z

# %%
pt1 = Point3D(1, 2, 3)
pt2 = Point3D(1, 1, 1)
dot_product_3d(pt1, pt2)

# %%
a = (1, 2)
b = (2, 3)
list(zip(a, b))

# %%
sum( e[0]*e[1] for e in zip(a, b))

# %%
def dot_product(a, b):
    return sum( e[0]*e[1] for e in zip(a, b))

dot_product(a, b)

# %%
Vector3D = namedtuple('Vector3D', 'x y z')

v1 = Vector3D(1, 2, 3)
v2 = Vector3D(3, 2, 1)

dot_product(v1, v2)

# %%
justnotaname = namedtuple('justaname', 'w x y z')

v11 = justnotaname(1, 2, 3, 4)
v22 = justnotaname(3, 2, 1, 5)

dot_product(v11, v22)

# %%
Circle = namedtuple('Circle', 'center_x, center_y     radius ')
c = Circle(0, 0, 10)
c.radius

# %%
Stock = namedtuple('Stock', '''symbol
                year
                month
                day
                open
                high
                low
                close''')

# %%
bse = Stock('BSE', 2018, 1, 25, 26_313, 26_458, 26_260, 26_393)
bse

# %%
bse.close, bse[-1]

# %%
for e in bse:
    print(e)

# %%
bse

# %%
symbol, *_, close = bse

# %%
symbol

# %%
symbol, year, month, day, *_, close = bse

symbol, year, close

# %%
print(_)

# %%
Person = namedtuple('Person', 'name age _ssn')

# %%
Person = namedtuple('Person', 'name age _ssn', rename=True)

# %%
Person._fields

# %%
Point3D._fields

# %%
Point2D._fields

# %%
Stock._fields

# %%
Stock._source
# https://docs.python.org/3/library/collections.html#namedtuple-factory-function-for-tuples-with-named-fields

# %%
Point3D.__dict__

# %%
Stock.__dict__

# %%
Vector3D = namedtuple('Vector3D', 'x y z')

v1 = Vector3D(1, 2, 3)

type(Vector3D)

# %%
b = bse._asdict()
b

# %%
b['symbol']

# %%
Point2D = namedtuple('Point2D', 'x y')

# %%
pt = Point2D(10, 20)

pt

# %%
pt[0]

# %%
pt[0] = 100

# %%
print(id(pt))
pt = Point2D(100, pt.y)
print(id(pt))

# %%
Stock = namedtuple('Stock', '''symbol
                year
                month
                day
                open
                high
                low
                close''')

bse = Stock('BSE', 2018, 1, 25, 26_313, 26_458, 26_260, 26_393)
bse

# %%
bse = Stock(bse.symbol, bse.year, bse.month, bse.day, bse.open, bse.high, bse.low, close = 100)

# %%
bse

# %%
*values, close = bse

# %%
close

# %%
values

# %%
values.append(26_393)
values

# %%
bse = Stock(*values)

# %%
bse

# %%
values = bse[:-1]
values

# %%
values + (100,)
# Out:
# ('BSE', 2018, 1, 25, 26313, 26458, 26260, 100)

# %%
bse = Stock(*(values + (100, )))

# %%
bse
# Out:
# Stock(symbol='BSE', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=100)

# %%
bse = Stock(*values, 10000)

# %%
bse = bse._replace(year=2019, open=10000)
bse
# Out:
# Stock(symbol='BSE', year=2019, month=1, day=25, open=10000, high=26458, low=26260, close=10000)

# %%
bse = Stock._make(values + (100,))

# %%
Point2D
# Out:
# __main__.Point2D

# %%
#Point3D = namedtuple('Point3D', 'x y z')  this is the easiest

# %%
Point2D._fields + ('z', )
# Out:
# ('x', 'y', 'z')

# %%
Point3D = namedtuple('Point3D', Point2D._fields + ('z',))
Point3D._fields
# Out:
# ('x', 'y', 'z')

# %%
Stock._fields
# Out:
# ('symbol', 'year', 'month', 'day', 'open', 'high', 'low', 'close')

# %%
StockExt = namedtuple('StockExt', Stock._fields + ('previous_change',))
StockExt._fields
# Out:
# ('symbol',
#  'year',
#  'month',
#  'day',
#  'open',
#  'high',
#  'low',
#  'close',
#  'previous_change')

# %%
Point3D = namedtuple('Point3D', Point2D._fields + ('z',))

pt3 = Point3D(*pt, 100)
pt3
# Out:
# Point3D(x=100, y=20, z=100)

# %%
bse_ext = StockExt(*bse, 1_000_000)
bse_ext
# Out:
# StockExt(symbol='BSE', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=100, previous_change=1000000)

# %%
Point2D = namedtuple('Point2D', 'x y')

Point2D.__doc__
# Out:
# 'Point2D(x, y)'

# %%
Point2D.__doc__ = "lost"

# %%
Point2D.__doc__
# Out:
# 'lost'

# %%
Point2D.x.__doc__
# Out:
# 'Alias for field number 0'

# %%
help(Point2D)
# Out:
# Help on class Point2D in module __main__:
#
# class Point2D(builtins.tuple)
#  |  Point2D(x, y)
#  |
#  |  lost
#  |
#  |  Method resolution order:
#  |      Point2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new OrderedDict which maps field names to their values.
#  |
#  |  _replace(_self, **kwds)
#  |      Return a new Point2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Point2D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(_cls, x, y)
#  |      Create new instance of Point2D(x, y)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  x
#  |      Alias for field number 0
#  |
#  |  y
#  |      Alias for field number 1
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  _fields = ('x', 'y')
#  |
#  |  _fields_defaults = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.tuple:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.

# %%
Point2D.__doc__ = '2D cartesian coordiante'
Point2D.x.__doc__ = 'x coordinate'
Point2D.y.__doc__ = 'y coordinate'
help(Point2D)
# Out:
# Help on class Point2D in module __main__:
#
# class Point2D(builtins.tuple)
#  |  Point2D(x, y)
#  |
#  |  2D cartesian coordiante
#  |
#  |  Method resolution order:
#  |      Point2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new OrderedDict which maps field names to their values.
#  |
#  |  _replace(_self, **kwds)
#  |      Return a new Point2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Point2D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(_cls, x, y)
#  |      Create new instance of Point2D(x, y)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  x
#  |      x coordinate
#  |
#  |  y
#  |      y coordinate
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  _fields = ('x', 'y')
#  |
#  |  _fields_defaults = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.tuple:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.

# %%
Vector2D = namedtuple('Vector2D', 'x1 x2 y1 y2 origin_x origin_y')

# %%
Vector2D._fields
# Out:
# ('x1', 'x2', 'y1', 'y2', 'origin_x', 'origin_y')

# %%
v1 = Vector2D(0, 0, 10, 10, 0, 0)

# %%
v1
# Out:
# Vector2D(x1=0, x2=0, y1=10, y2=10, origin_x=0, origin_y=0)

# %%
vector_zero = Vector2D(0, 0, 0, 0, 0, 0)
vector_zero
# Out:
# Vector2D(x1=0, x2=0, y1=0, y2=0, origin_x=0, origin_y=0)

# %%
v2 = vector_zero._replace(x1=10, y1=10, x2=20, y2=20)
v2
# Out:
# Vector2D(x1=10, x2=20, y1=10, y2=20, origin_x=0, origin_y=0)

# %%
def func(a, b=1, c=20):
    print(a, b, c)

func(1)
# Out:
# 1 1 20

# %%
func.__defaults__
# Out:
# (1, 20)

# %%
func.__defaults__ = 455, 900

func(1)
# Out:
# 1 455 900

# %%
func.__defaults__ = (2, 40)
func(10)
# Out:
# 10 2 40

# %%
func.__defaults__ = (20, 90, 90)

# %%
func()
# Out:
# 20 90 90

# %%
help(Vector2D)
# Out:
# Help on class Vector2D in module __main__:
#
# class Vector2D(builtins.tuple)
#  |  Vector2D(x1, x2, y1, y2, origin_x, origin_y)
#  |
#  |  Vector2D(x1, x2, y1, y2, origin_x, origin_y)
#  |
#  |  Method resolution order:
#  |      Vector2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new OrderedDict which maps field names to their values.
#  |
#  |  _replace(_self, **kwds)
#  |      Return a new Vector2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Vector2D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(_cls, x1, x2, y1, y2, origin_x, origin_y)
#  |      Create new instance of Vector2D(x1, x2, y1, y2, origin_x, origin_y)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  x1
#  |      Alias for field number 0
#  |
#  |  x2
#  |      Alias for field number 1
#  |
#  |  y1
#  |      Alias for field number 2
#  |
#  |  y2
#  |      Alias for field number 3
#  |
#  |  origin_x
#  |      Alias for field number 4
#  |
#  |  origin_y
#  |      Alias for field number 5
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  _fields = ('x1', 'x2', 'y1', 'y2', 'origin_x', 'origin_y')
#  |
#  |  _fields_defaults = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.tuple:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.

# %%
type(Vector2D.__new__.__defaults__)
# Out:
# NoneType

# %%
Vector2D.__new__.__defaults__ = (0, 0)
v1 = Vector2D(10, 10, 20, 20)

# %%
v1
# Out:
# Vector2D(x1=10, x2=10, y1=20, y2=20, origin_x=0, origin_y=0)

# %%
Vector2D.__new__.__defaults__ = (-10, -10)
v1 = Vector2D(10, 10, 20, 20)
v1
# Out:
# Vector2D(x1=10, x2=10, y1=20, y2=20, origin_x=-10, origin_y=-10)

# %%
from random import randint, random
from collections import namedtuple

# %%
def random_color():
    red = randint(0, 255)
    green = randint(0, 255)
    blue = randint(0, 255)
    alpha = randint(0, 255)
    return red, green, blue, alpha

# %%
color = random_color()

# %%
Color = namedtuple('Color', 'red green blue alpha')

def random_color():
    red = randint(0, 255)
    green = randint(0, 255)
    blue = randint(0, 255)
    alpha = randint(0, 255)
    return Color(red, green, blue, alpha)

# %%
color = random_color()

# %%
color.alpha
# Out:
# 226

# %%
Vector2D.__new__.__defaults__ = (-10, -10, 10, 10, 10, 10, 10, 10)
v1 = Vector2D(10, 10, 20, 20)
v1
# Out:
# Vector2D(x1=10, x2=10, y1=20, y2=20, origin_x=10, origin_y=10)

# %%
data_dict = dict(key1=100, key2=200, key3=300)

# %%
data_dict['key1']
# Out:
# 100

# %%
Data = namedtuple('Data', data_dict.keys())

# %%
Data._fields
# Out:
# ('key1', 'key2', 'key3')

# %%
data_dict.values()
# Out:
# dict_values([100, 200, 300])

# %%
d1 = Data(data_dict.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-236-771b44d24bdd> in <module>
# ----> 1 d1 = Data(data_dict.values())
#
# TypeError: __new__() missing 2 required positional arguments: 'key2' and 'key3'

# %%
type(data_dict.values())
# Out:
# dict_values

# %%
from collections.abc import Iterable

isinstance(data_dict.values(), Iterable)
# Out:
# True

# %%
d1 = Data(*data_dict.values())

# %%
d1
# Out:
# Data(key1=100, key2=200, key3=300)

# %%
d2 = Data(key1=10, key2=20, key3=30)
d2
# Out:
# Data(key1=10, key2=20, key3=30)

# %%
data_dict
# Out:
# {'key1': 100, 'key2': 200, 'key3': 300}

# %%
d2 = Data(**data_dict)
d2
# Out:
# Data(key1=100, key2=200, key3=300)

# %%
key_name = 'key2'
data_dict[key_name]
# Out:
# 200

# %%
d2.key_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-246-ec759ca66e50> in <module>
# ----> 1 d2.key_name
#
# AttributeError: 'Data' object has no attribute 'key_name'

# %%
getattr(d2, key_name)
# Out:
# 200

# %%
print(data_dict.get('key10', None))
# Out:
# None

# %%
print(getattr(d2, 'key10', None))
# Out:
# None

# %%
# !pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-4.1.3-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.4 in /opt/venv/lib/python3.7/site-packages (from Faker) (2.8.1)
# Collecting text-unidecode==1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.2 MB/s  eta 0:00:01
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.7/site-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Installing collected packages: text-unidecode, Faker
# Successfully installed Faker-4.1.3 text-unidecode-1.3
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
from faker import Faker
fake = Faker()

fake.profile()
# Out:
# {'job': 'Emergency planning/management officer',
#  'company': 'Cherry, Ellis and Graves',
#  'ssn': '630-91-5549',
#  'residence': '4735 Greer Road Apt. 461\nLake Lauraview, RI 03660',
#  'current_location': (Decimal('-81.398229'), Decimal('4.283934')),
#  'blood_group': 'AB+',
#  'website': ['https://higgins.net/',
#   'https://howell.net/',
#   'http://www.ramos.info/'],
#  'username': 'eileenbrown',
#  'name': 'Michelle Diaz',
#  'sex': 'F',
#  'address': '209 Hinton Center\nNorth Stephanie, NY 40503',
#  'mail': 'vgeorge@yahoo.com',
#  'birthdate': datetime.date(2014, 1, 14)}

# %%
fake.profile()
# Out:
# {'job': 'Charity fundraiser',
#  'company': 'Austin, Taylor and Hubbard',
#  'ssn': '699-32-1360',
#  'residence': '3256 Ochoa Meadow Apt. 240\nNew Jessica, CO 90684',
#  'current_location': (Decimal('81.988212'), Decimal('-17.648536')),
#  'blood_group': 'O+',
#  'website': ['https://fuentes.info/'],
#  'username': 'john96',
#  'name': 'Alicia Torres',
#  'sex': 'F',
#  'address': 'Unit 0894 Box 5175\nDPO AA 98445',
#  'mail': 'alexis69@gmail.com',
#  'birthdate': datetime.date(1965, 10, 12)}

# %%
fake.company()
# Out:
# 'Briggs Group'
